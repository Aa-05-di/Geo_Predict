# %%
import pandas as pd

# %%
df=pd.read_csv("GEO_PREDICT/Geo_Predict/WEB_SCRAPED/news_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv("GEO_PREDICT/Geo_Predict/WEB_SCRAPED/news_data.csv")
#
# File /opt/anaconda3/envs/tf-macos/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

load_dotenv()
"GOOGLE_API_KEY" =

model_names = [
    "gemini-pro",
    "gemini-pro-vision",
    "models/gemini-pro",
    "models/gemini-pro-vision",
    "gemini-flash",
    "gemini-nano",
    "gemini-flash-lite",
    "gemini-2.5-pro-preview-03-25"
]

for model_name in model_names:
    try:
        llm = ChatGoogleGenerativeAI(model=model_name, temperature=0.6)
        response = llm.invoke("Hello, how are you?")
        print(f"Model: {model_name}, Response: {response.content}")
    except Exception as e:
        print(f"Model: {model_name}, Error: {e}")
# Out:
#   Cell In[13], line 6
#     "GOOGLE_API_KEY" =
#     ^
# SyntaxError: cannot assign to literal

# %%
import pandas as pd

df1=pd.read_csv("GEO_PREDICT/Geo_Predict/WEB_SCRAPED/news_data.csv")

# %%
df1
# Out:
#                                              Headline  \
# 0   Salah laps up contract acclaim - now Van Dijk ...
# 1   Australia's looming election brings housing cr...
# 2   Severe floods hit Lanzarote after torrential rain
# 3       How industry leaders transformed their career
# 4   Relatives charged after boy, nine, killed in a...
# ..                                                ...
# 90  Ukraine's allies condemn Russia over deadly mi...
# 91  Two American Airlines jets clip wings on groun...
# 92  'A fascinating contrast between team-mates and...
# 93  Trump's iPhone olive branch is a significant t...
# 94     UK economy grew more than expected in February
#
#                                           Description         Time  \
# 0   Mohamed Salah's goal and assist numbers show h...   11 hrs ago
# 1   Australia's housing crisis has hit its worst p...    2 hrs ago
# 2   A state of emergency was declared in the Spani...   12 hrs ago
# ...

# %%
df1["Headline"][4]
# Out:
# 'Relatives charged after boy, nine, killed in accidental shooting'
